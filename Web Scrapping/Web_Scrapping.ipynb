# %% [markdown]
# ## Importing Libraries

# %% [markdown]
# <h5><b><u> Code Written by Chirag Lalwani </b></u> </h5>

# %%
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

# %%
my_url=  "https://www.flipkart.com/search?q=samsung+mobiles&amp;sid=tyy%2C4io&amp;as=on&amp;as-show=on&amp;otracker=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&amp;otracker1=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&amp;as-pos=1&amp;as-type=RECENT&amp;suggestionId=samsung+mobiles%7CMobiles&amp;requestId=18944876-a6ef-44c0-ac67-d31d7b11a548&amp;as-backfill=on"
uClient= uReq(my_url)
page_html= uClient.read()
uClient.close()

# %%
uClient

# %%
my_url

# %%
page_html

# %%
page_soup= soup(page_html)
page_soup

# %% [markdown]
# ## Inspect tht page and find class

# %%
containers= page_soup.findAll("div", {"class": "_13oc-S"})
print(len(containers))
# Out:
# 24

# %% [markdown]
# ## Storing in flipkart.csv

# %%
import re
filename= "flipkart.csv"
f= open(filename, "w",encoding="UTF-8")

headers= "Mobile_Name,Price,Ratings,Technical_Specifications\n"
f.write(headers)

for container in containers:
    name= container.findAll('div',{"class":"_4rR01T"})
    Name= name[0].text
    Name = re.sub(r"[\(\)]",'',Name)
    Name=Name.replace(",","")
    price= container.findAll("div", {"class": "_30jeq3 _1_WHN1"})
    Price=price[0].text
    Price=Price.replace(",","")
    Price = re.sub('[^A-Za-z0-9]+', '', Price)
    rating=container.findAll("div", {"class": "_3LWZlK"})
    Ratings=rating[0].text
    specification =container.findAll("ul", {"class": "_1xgFaf"})
    Specification=specification[0].text

    f.write(Name + ","+ Price + "," + Ratings + "," + Specification+"\n")

  
f.close()

# %%
import pandas as pd
data = pd.read_csv("flipkart.csv", encoding="latin-1")
data
# Out:
#                                      Mobile_Name  Price  Ratings  \
# 0           SAMSUNG Galaxy F22 Denim Black 64 GB  11999      4.3
# 1            SAMSUNG Galaxy F22 Denim Blue 64 GB  11999      4.3
# 2          SAMSUNG Galaxy F22 Denim Black 128 GB  13999      4.3
# 3         SAMSUNG Galaxy F23 5G Aqua Blue 128 GB  16999      4.1
# 4           SAMSUNG Galaxy M32 Light Blue 128 GB  14550      4.3
# 5           SAMSUNG Galaxy F22 Denim Blue 128 GB  13999      4.3
# 6   SAMSUNG Galaxy M33 5G Deep Ocean Blue 128 GB  16725      4.0
# 7         SAMSUNG Galaxy F23 5G Aqua Blue 128 GB  15999      4.1
# 8                SAMSUNG Galaxy M32 Black 128 GB  14590      4.3
# 9      SAMSUNG Galaxy F23 5G Copper Blush 128 GB  16999      4.1
# 10                          SAMSUNG GURU MUSIC 2   1994      4.2
# 11     SAMSUNG Galaxy F23 5G Forest Green 128 GB  16999      4.1
# 12                               SAMSUNG GURU GT   1494      4.1
# 13                          SAMSUNG Guru Music 2   1994      4.1
# 14   SAMSUNG Galaxy M33 5G Mystique Green 128 GB  16749      4.0
# 15                          SAMSUNG Guru Music 2   1994      4.3
# 16                          SAMSUNG Guru Music 2   1994      4.3
# 17                               SAMSUNG GURU GT   1494      4.1
# 18                 SAMSUNG Galaxy M12 Blue 64 GB  10285      4.2
# 19                SAMSUNG Galaxy M12 Black 64 GB  11300      4.2
# 20                 SAMSUNG Guru Music 2 SM-B315E   1994      4.2
# 21                              SAMSUNG GT-E1215   1494      4.3
# 22      SAMSUNG Galaxy F12 Celestial Black 64 GB  11499      4.3
# 23            SAMSUNG Galaxy F12 Sea Green 64 GB  11499      4.3
#
#                              Technical_Specifications
# 0   4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16....
# 1   4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16....
# 2   6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 3   6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 4   6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 5   6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 6   6 GB RAM | 128 GB ROM16.76 cm (6.6 inch) Displ...
# 7   4 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 8   6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 9   6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 10  8 MB RAM | 0 GB ROM | Expandable Upto 16 GB5.0...
# 11  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 12  0 MB ROM3.81 cm (1.5 inch) Display800 mAh Batt...
# 13  0.53 RAM | NA KB ROM | Expandable Upto 16 GB5....
# 14  6 GB RAM | 128 GB ROM16.76 cm (6.6 inch) Displ...
# 15  NA ROM5.08 cm (2 inch) NA Display800 mAh Batte...
# 16  NA ROM5.08 cm (2 inch) NA Display800 mAh Batte...
# 17  153 MB RAM | 153 MB ROM3.81 cm (1.5 inch) Disp...
# 18  4 GB RAM | 64 GB ROM16.51 cm (6.5 inch) Displa...
# 19  4 GB RAM | 64 GB ROM16.51 cm (6.5 inch) Displa...
# 20  Expandable Upto 16 GB5.08 cm (2 inch) QVGA Dis...
# 21  NA ROM3.81 cm (1.5 inch) NA Display800 mAh Bat...
# 22  4 GB RAM | 64 GB ROM | Expandable Upto 512 GB1...
# 23  4 GB RAM | 64 GB ROM | Expandable Upto 512 GB1...

# %%
#html upload
my_url=  "https://www.amazon.in/s?k=samsung&rh=n%3A1389401031&ref=nb_sb_noss"
uClient= uReq(my_url)
page_html= uClient.read()
uClient.close()

# %%
uClient

# %%
my_url

# %%
page_html

# %%
page_soup= soup(page_html)
page_soup

# %%
containers= page_soup.findAll('div', {"class":"sg-col sg-col-4-of-12 sg-col-8-of-16 sg-col-12-of-20 s-list-col-right"})
containers
print(len(containers))
# Out:
# 24

# %%
filename= "amazon.csv"
f= open(filename, "w")

headers= "Mobile_Name,Price,Ratings,Links,Discounts\n"
f.write(headers)

for phone in containers:
    name= phone.findAll("span",{"class":"a-size-medium a-color-base a-text-normal"})
    Name= name[0].text
    Name=Name.replace(",","")
    link=phone.findAll("a")
    Link=link[0].attrs['href']
    price= phone.findAll("span", {"class": "a-offscreen"})
    Price=price[0].text
    Price = re.sub('[^A-Za-z0-9]+', '', Price)
    rating=phone.findAll("span", {"class": "a-icon-alt"})
    Ratings=rating[0].text
    discount =phone.findAll("span", {"class": None})
    Discount=discount[4].text
    print(Name + ","+ Price + "," + Ratings + ","+Link+"," + Discount+"\n")
    f.write(Name + ","+ Price + "," + Ratings + ","+Link+"," + Discount+"\n")
f.close()

# %%
import pandas as pd
data1 = pd.read_csv("amazon.csv", encoding="latin-1")
data1
# Out:
#                                           Mobile_Name  Price  \
# 0   Samsung Galaxy M12 (Blue4GB RAM 64GB Storage) ...  10499
# 1   Samsung Galaxy M12 (Black4GB RAM 64GB Storage)...  10499
# 2   Samsung Galaxy M32 (Light Blue 6GB RAM 128GB |...  16999
samsung-Galaxy-Cloud-128GB-Storage/dp/B08VB2MRF8
# 21  4.2 out of 5 stars  /Samsung-Galaxy-Bluetooth-Compatible-Android/d...
# 22  4.1 out of 5 stars    /Samsung-Guru-Music-GT-B315-Black/dp/B09MKT9ZYM
# 23  3.9 out of 5 stars  /Samsung-Mystique-Storage-Purchased-Separately...
#
#     Discounts
# 0   (19% off)
# 1   (19% off)
# 2   (11% off)
# 3   (12% off)
# 4   (51% off)
# 5   (12% off)
# 6   (24% off)
# 7   (11% off)
# 8   (25% off)
# 9   (23% off)
# 10  (58% off)
# 11  (12% off)
# 12  (28% off)
# 13  (29% off)
# 14  (17% off)
# 15  (18% off)
# 16  (13% off)
# 17  (20% off)
# 18  (25% off)
# 19  (16% off)
# 20  (51% off)
# 21  (49% off)
# 22  (20% off)
# 23  (28% off)

# %% [markdown]
# Create a CSV file for the Task A &amp; B containing all the possible details.
#
# a. Get the phone details with min and max price of the phone in Amazon &amp; flipkart.
#
# b. Get the price of Samsung Galaxy F12 options available with price comparison in
# Amazon &amp; flipkart.

# %%
amz2=pd.DataFrame(data1[data1.Price == data1.Price.max()])
amz3=pd.DataFrame(data1[data1.Price == data1.Price.min()])
print("Maximum Price in Amazon")
amz2
# Out:
# Maximum Price in Amazon
#                                           Mobile_Name  Price  \
# 4   Samsung Galaxy S20 FE 5G (Cloud Navy 8GB RAM 1...  36990
# 20  Samsung Galaxy S20 FE 5G (Cloud Mint 8GB RAM 1...  36990
#
#                Ratings                                              Links  \
# 4   4.4 out of 5 stars  /Samsung-Galaxy-Cloud-128GB-Storage/dp/B08VB57558
# 20  4.4 out of 5 stars  /Samsung-Galaxy-Cloud-128GB-Storage/dp/B08VB2MRF8
#
#     Discounts
# 4   (51% off)
# 20  (51% off)

# %%
print("Minimum Price in Amazon")
amz3
# Out:
# Minimum Price in Amazon
#                                           Mobile_Name  Price  \
# 19  Samsung EHS64 EHS64AVFWECINU Wired In Ear Earp...    419
#
#                Ratings                                              Links  \
# 19  4.2 out of 5 stars  /Samsung-Original-EHS64AVFWECINU-Stereo-Headse...
#
#     Discounts
# 19  (16% off)

# %%
data
# Out:
#                   Name  Rating        Ram   Battery  Price
# 0   SAMSUNG Galaxy F22     4.3  4 GB RAM   6000 mAh   11999
# 1   SAMSUNG Galaxy F22     4.3  6 GB RAM   6000 mAh   13999
# 2   SAMSUNG Galaxy F22     4.3  4 GB RAM   6000 mAh   11999
# 3   SAMSUNG Galaxy F23     4.1  6 GB RAM   5000 mAh   16999
# 4   SAMSUNG Galaxy F23     4.1  6 GB RAM   5000 mAh   16999
# 5   SAMSUNG Galaxy F22     4.3  6 GB RAM   6000 mAh   13999
# 6   SAMSUNG Galaxy M33     4.0  6 GB RAM   6000 mAh   16729
# 7   SAMSUNG Galaxy F23     4.1  4 GB RAM   5000 mAh   15999
# 8   SAMSUNG Galaxy M32     4.3  6 GB RAM   6000 mAh   14590
# 9   SAMSUNG Galaxy F23     4.1  6 GB RAM   5000 mAh   16999
# 10  SAMSUNG GURU MUSIC     4.2  8 MB RAM   800 mAh     1994
# 11  SAMSUNG Galaxy M12     4.2  4 GB RAM   6000 mAh   10285
# 12  SAMSUNG Galaxy M33     4.0  6 GB RAM   6000 mAh   16749
.1 out of 5 stars  /Samsung-Galaxy-Storage-Months-Replacement/dp/...
# 12  3.9 out of 5 stars  /Samsung-Storage-Adapter-Purchased-Separately/...
# 13  3.9 out of 5 stars    /Samsung-Guru-1215-GT-E1215-Black/dp/B09MTVDZCL
# 14  3.6 out of 5 stars  /Samsung-Storage-Additional-Exchange-SM-A135FL...
# 15  3.8 out of 5 stars  /Samsung-Galaxy-Storage-Additional-Exchange/dp...
# 16  4.1 out of 5 stars  /Samsung-Galaxy-Slate-Black-Storage/dp/B09CGLRLYM
# 17  3.8 out of 5 stars  /Samsung-Mystique-Storage-Purchased-Separately...
# 18  3.6 out of 5 stars  /Samsung-Storage-Additional-Exchange-SM-A135FL...
# 19  4.2 out of 5 stars  /Samsung-Original-EHS64AVFWECINU-Stereo-Headse...
# 20  4.4 out of 5 stars  /Samsung-Galaxy-Cloud-128GB-Storage/dp/B08VB2MRF8
# 21  4.2 out of 5 stars  /Samsung-Galaxy-Bluetooth-Compatible-Android/d...
# 22  4.1 out of 5 stars    /Samsung-Guru-Music-GT-B315-Black/dp/B09MKT9ZYM
# 23  3.9 out of 5 stars  /Samsung-Mystique-Storage-Purchased-Separately...
#
#     Discounts
# 0   (19% off)
# 1   (19% off)
# 2   (11% off)
# 3   (12% off)
# 4   (51% off)
# 5   (12% off)
# 6   (24% off)
# 7   (11% off)
# 8   (25% off)
# 9   (23% off)
# 10  (58% off)
# 11  (12% off)
# 12  (28% off)
# 13  (29% off)
# 14  (17% off)
# 15  (18% off)
# 16  (13% off)
# 17  (20% off)
# 18  (25% off)
# 19  (16% off)
# 20  (51% off)
# 21  (49% off)
# 22  (20% off)
# 23  (28% off)

# %%
flipkart1=pd.DataFrame(data[data.Price == data.Price.max()])
flipkart2=pd.DataFrame(data[data.Price == data.Price.min()])
print("Maximum Price")
flipkart1
# Out:
# Maximum Price
#                                   Mobile_Name  Price  Ratings  \
# 3      SAMSUNG Galaxy F23 5G Aqua Blue 128 GB  16999      4.1
# 9   SAMSUNG Galaxy F23 5G Copper Blush 128 GB  16999      4.1
# 11  SAMSUNG Galaxy F23 5G Forest Green 128 GB  16999      4.1
#
#                              Technical_Specifications
# 3   6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 9   6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 11  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...

# %%
print("Minimum price")
flipkart2
# Out:
# Minimum price
#          Mobile_Name  Price  Ratings  \
# 12   SAMSUNG GURU GT   1494      4.1
# 17   SAMSUNG GURU GT   1494      4.1
# 21  SAMSUNG GT-E1215   1494      4.3
#
#                              Technical_Specifications
# 12  0 MB ROM3.81 cm (1.5 inch) Display800 mAh Batt...
# 17  153 MB RAM | 153 MB ROM3.81 cm (1.5 inch) Disp...
# 21  NA ROM3.81 cm (1.5 inch) NA Display800 mAh Bat...

# %% [markdown]
# b. Get the price of Samsung Galaxy F12 options available with price comparison in
# Amazon &amp; flipkart.

# %%
phone = data.loc[(data['Mobile_Name'] == 'SAMSUNG Galaxy F12 Celestial Black 64 GB') | (data['Mobile_Name'] == 'SAMSUNG Galaxy F12 Sea Green 64 GB')]
phone
# Out:
#                                  Mobile_Name  Price  Ratings  \
# 22  SAMSUNG Galaxy F12 Celestial Black 64 GB  11499      4.3
# 23        SAMSUNG Galaxy F12 Sea Green 64 GB  11499      4.3
#
#                              Technical_Specifications
# 22  4 GB RAM | 64 GB ROM | Expandable Upto 512 GB1...
# 23  4 GB RAM | 64 GB ROM | Expandable Upto 512 GB1...
